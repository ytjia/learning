# %%
import urllib2import json

# %%
PARTITION = '------------------------------'URL = 'http://api.mobile.meituan.com/hotel/v1/hotel/1/schools'def json_parser(json_data):    value = json.loads(json_data)      root_list = value.keys()      print root_list      print PARTITION      for root_key in root_list:          ff_value = value[root_key]          # print ff_value        for item in ff_value:            print item            for key in item:                print key + ' : ' + unicode(item[key])    print PARTITION      def register_url(input_url):      try:           data = urllib2.urlopen(input_url).read()          return data      except Exception,e:          print e

# %%
data = register_url(URL)

# %%
json_parser(data)
# Out:
# [u'data']------------------------------{u'name': u'\u5317\u65b9\u5de5\u4e1a\u5927\u5b66', u'order': 0, u'cityId': 1, u'lat': 39.934600830078125, u'lng': 116.21477508544922, u'id': 466834}name : 北方工业大学order : 0cityId : 1lat : 39.9346008301lng : 116.214775085id : 466834{u'name': u'\u5317\u4eac\u57ce\u5e02\u5b66\u9662', u'order': 1, u'cityId': 1, u'lat': 39.993003845214844, u'lng': 116.35340118408203, u'id': 386009}name : 北京城市学院order : 1cityId : 1lat : 39.9930038452lng : 116.353401184id : 386009{u'name': u'\u5317\u4eac\u5927\u5b66', u'order': 2, u'cityId': 1, u'lat': 39.99776077270508, u'lng': 116.31616973876953, u'id': 386351}name : 北京大学order : 2cityId : 1lat : 39.9977607727lng : 116.316169739id : 386351{u'name': u'\u5317\u4eac\u7535\u5f71\u5b66\u9662', u'order': 3, u'cityId': 1, u'lat': 39.97782897949219, u'lng': 116.36238098144531, u'id': 3192105}name : 北京电影学院order : 3cityId : 1lat : 39.9778289795lng : 116.362380981id : 3192105{u'name': u'\u5317\u4eac\u670d\u88c5\u5b66\u9662', u'orde
# ...
