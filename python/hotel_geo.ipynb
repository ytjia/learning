# %%
import pandas as pd

# %%
file_path = '/Users/ytjia/Downloads/Hotel/geo_analysis/travel_city_stat'oloc = pd.read_table(file_path, sep = '\t')oloc.head(5)
# Out:
#    cnt_cities  cnt_users0           1   426373501           2    59755482           3    14931383           4     4872834           5     188837

# %%
oloc_city = oloc.set_index('cnt_cities')oloc_perc = oloc_city * 1.0 / oloc_city.sum()oloc_perc.plot(kind='bar')

# %%
log(oloc_city).plot()
